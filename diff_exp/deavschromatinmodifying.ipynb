# %%
import pandas as pd

posneg = pd.read_csv("data/posvsnegDEA.csv",index_col=0)
genelist = set(pd.read_csv("data/wntgenes-entrezids.txt",header=None)[0])
#genelist = set(pd.read_csv("../raw-data/gene-lists/wntgenes-entrezids.txt",header=None)[0])

posneg
# Out:
#                      baseMean  log2FoldChange     lfcSE      stat  \
# row
# ?|340602             4.911949       -4.546702  0.685960 -6.628236
# ?|553137            12.022576       -4.391634  1.102215 -3.984371
# ?|57714            956.504785       -1.511397  0.234177 -6.454084
# ?|645851            16.208553       -0.879327  0.277539 -3.168300
# ?|729884             9.519404        2.599189  0.579938  4.481842
# ...                       ...             ...       ...       ...
# ZXDC|79364        2126.802746       -0.332450  0.080473 -4.131219
# ZYG11A|440590      127.079626       -1.897947  0.415658 -4.566130
# ZYG11B|79699      1306.580253       -0.256595  0.088628 -2.895206
# ZZZ3|26009        1421.944721       -0.400674  0.101425 -3.950462
# psiTPTE22|387590    58.928865       -2.420342  0.421943 -5.736184
#
#                         pvalue          padj
# row
# ?|340602          3.397222e-11  2.133114e-09
# ?|553137          6.765915e-05  6.236598e-04
# ...

# %%
selected = posneg.loc[[x for x in posneg.index if int(x.split("|")[1]) in genelist]]
selected.to_csv("output/short_genes/deaconfluencewithwntgenes_posneg.csv")
#selected.to_csv("deaconfluencewithwntgenes_posneg.csv")

selected
# Out:
#                      baseMean  log2FoldChange     lfcSE      stat  \
# row
# APC2|10297          20.849809        1.321455  0.343977  3.841696
# AXIN1|8312        2534.039649        0.250502  0.100564  2.490983
# AXIN2|8313        1587.042774        1.053401  0.344151  3.060866
# BAMBI|25805       2025.870757        1.670394  0.395351  4.225087
# BTRC|8945         1040.591117        0.240552  0.097744  2.461035
# CACYBP|27101      5330.390256        0.593716  0.125691  4.723604
# CAMK2D|817        1123.724178        0.748121  0.199391  3.752021
# CCND1|595         7824.267472        0.841722  0.243462  3.457307
# CCND3|896         2515.904721       -0.391209  0.141446 -2.765790
# CSNK1A1|1452      9440.519996        0.266730  0.095880  2.781925
# CTNNBIP1|56998    2778.263903        0.628826  0.155848  4.034864
# DKK1|22943         880.482922        3.028718  0.644521  4.699174
# DKK2|27123          83.375620       -1.091283  0.441729 -2.470481
# ...
